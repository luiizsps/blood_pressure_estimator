# %%
# import necessary libraries
import pandas as pd 
import numpy as np
import pickle
import torch
import math
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mean
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import 
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow import keras
import os
import random
import keras_tuner as kt
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import ccf

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
# load data
path = "../datasets/CNAP_blood_pressure.csv"

df = pd.read_csv(path)
df.head()
# Out:
#    ecg_0  ecg_1  ecg_2  ecg_3  ecg_4  ecg_5  ecg_6  ecg_7  ecg_8  ecg_9  ...  \
# 0 -784.0 -754.0 -732.0 -715.0 -689.0 -671.0 -658.0 -646.0 -638.0 -637.0  ...
# 1  686.0  680.0  298.0 -294.0 -688.0 -596.0 -101.0  442.0  717.0  715.0  ...
# 2  590.0  560.0  107.0 -534.0 -871.0 -632.0  -32.0  511.0  748.0  740.0  ...
# 3  633.0  582.0  164.0 -412.0 -729.0 -529.0   17.0  523.0  724.0  691.0  ...
# 4  694.0  424.0 -138.0 -671.0 -805.0 -463.0  119.0  573.0  695.0  653.0  ...
#
#     ppg_94   ppg_95   ppg_96   ppg_97   ppg_98   ppg_99         SBP  \
# 0  56603.0  56608.0  56612.0  56581.0  56551.0  56557.0  131.607056
# 1  56247.0  56227.0  56203.0  56213.0  56224.0  56207.0  131.607056
# 2  56374.0  56364.0  56351.0  56373.0  56399.0  56397.0  127.789307
# 3  56939.0  56922.0  56904.0  56922.0  56942.0  56930.0  128.906250
# 4  56378.0  56367.0  56388.0  56408.0  56394.0  56378.0  125.912476
#
#          DBP  subject  trial
# 0  58.044434        0    1.0
# 1  58.044434        0    1.0
# 2  57.366943        0    1.0
# 3  55.453491        0    1.0
# 4  55.142212        0    1.0
#
# [5 rows x 304 columns]

# %%
df.describe()
# Out:
#               ecg_0         ecg_1         ecg_2         ecg_3         ecg_4  \
# count  16047.000000  16047.000000  16047.000000  16047.000000  16047.000000
# mean    1066.188945    431.663613  -1184.575871  -2584.160404  -2717.941609
# std      596.022072    535.347140   1113.145288   1764.257444   1902.970274
# min    -5336.000000  -3104.000000  -5561.000000  -8135.000000  -8159.000000
# 25%      641.000000    143.000000  -1963.500000  -3912.500000  -4168.500000
# 50%      780.000000    418.000000   -931.000000  -2302.000000  -2233.000000
# 75%     1637.500000    656.000000   -244.000000  -1088.500000  -1337.500000
# max     4394.000000   3014.000000   1375.000000    946.000000    838.000000
#
#               ecg_5         ecg_6         ecg_7         ecg_8         ecg_9  \
# count  16047.000000  16047.000000  16047.000000  16047.000000  16047.000000
# mean   -1756.763881   -644.251387     52.182402    383.462890    527.773914
# std     1624.898566   1101.846380    532.029296    249.209632    288.587199
# min    -7152.000000  -4674.000000  -2434.000000  -1592.000000  -1497.000000
# 25%    -2798.500000  -1271.500000   -216.000000    226.000000    323.000000
# 50%    -1286.000000   -169.000000    157.000000    344.000000    491.000000
# 75%     -460.500000    129.000000    391.000000    499.000000    716.000000
# max     1112.000000   2779.000000   2688.000000   2597.000000   2754.000000
#
#        ...       ppg_94        ppg_95        ppg_96        ppg_97  \
# count  ...  16047.00000  16047.000000  16047.000000  16047.000000
# mean   ...  43437.17536  43437.930953  43438.393968  43438.538605
# std    ...  18823.48963  18824.907741  18826.414014  18827.809178
# min    ...  19505.00000  19481.000000  19474.000000  19463.000000
# 25%    ...  27992.50000  27994.500000  27999.500000  27995.000000
# 50%    ...  35665.00000  35665.000000  35669.000000  35671.000000
# 75%    ...  59455.50000  59460.000000  59467.000000  59476.000000
# max    ...  83872.00000  83911.000000  83950.000000  83938.000000
#
#              ppg_98        ppg_99           SBP           DBP       subject  \
# count  16047.000000  16047.000000  16047.000000  16047.000000  16047.000000
# mean   43438.402817  43438.024553    123.233116     65.425236      3.436219
# std    18828.936537  18829.911345     17.885018     12.599646      2.226186
# min    19443.000000  19433.000000     72.106934     27.767944      0.000000
# 25%    27992.500000  27983.000000    111.749268     56.675720      2.000000
# 50%    35664.000000  35662.000000    123.074341     64.022827      3.000000
# 75%    59479.000000  59481.000000    133.680725     73.104858      5.000000
# max    83925.000000  83961.000000    191.830444    123.944092      7.000000
#
#               trial
# count  16047.000000
# mean       2.504393
# std        1.117698
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
#
# [8 rows x 304 columns]

# %%
# x y split
feature_cols = df.columns[:300]
target_cols = ['SBP', 'DBP']
groups = df['subject'].values

X = df[feature_cols].values
y = df[target_cols].values

# %%
groups.shape
# Out:
# (16047,)

# %%
# apply StandardScaler
scaler_x = StandardScaler()
scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)
X = scaler_x.fit_transform(X)

# %%
X.shape
# Out:
# (16047, 300)

# %%
logo = LeaveOneGroupOut()

# %%
def plot_predictions(test_prediction, y_test):
    """
    Plot the actual vs predicted values for systolic and diastolic blood pressure.
    
    Parameters:
    test_prediction (array): Predicted values with shape (n_samples, 2)
    y_test (array): True values with shape (n_samples, 2)
    """
    
    test_dict = {
        "Systolic": y_test[:, 0],
        "Diastolic": y_test[:, 1],
    }
    prediction_dict = {
        "Systolic": test_prediction[:, 0],
        "Diastolic": test_prediction[:, 1],
    }
    
    test_df = pd.DataFrame(test_dict)
    prediction_df = pd.DataFrame(prediction_dict)
    
    fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 8), sharex=True)
    
    axs[0].plot(test_df["Systolic"], color='blue', label="True")
    axs[0].plot(prediction_df["Systolic"], color='#1f77b4', label="Predicted")
    axs[0].set_title("Systolic Blood Pressure")
    axs[0].legend()
    axs[0].grid(True)
    
    axs[1].plot(test_df["Diastolic"], color='green', label="True")
    axs[1].plot(prediction_df["Diastolic"], color='#2ca02c', label="Predicted")
    axs[1].set_title("Diastolic Blood Pressure")
    axs[1].legend() 
    axs[1].grid(True)
    
    plt.xlabel("Sample Index") 
    plt.tight_layout()
    plt.show()

# %%
def calc_error_avg_bp(y_predicted, y_true):
    """Calculate the absolute difference between the average true and average predicted blood pressure"""

    true_dict = {
        "Systolic": y_true[:, 0],
        "Diastolic": y_true[:, 1],
    }

    prediction_dict = {
        "Systolic": y_predicted[:, 0],
        "Diastolic": y_predicted[:, 1],
    }

    avg_true_systolic = mean(true_dict["Systolic"])
    avg_predicted_systolic = mean(prediction_dict["Systolic"])

    avg_true_diastolic = mean(true_dict["Diastolic"])
    avg_predicted_diastolic = mean(prediction_dict["Diastolic"])

    # Cálculo dos erros
    erro_systolic = avg_predicted_systolic - avg_true_systolic
    erro_diastolic = avg_predicted_diastolic - avg_true_diastolic

    # Arquivo de saída
    arquivo = "saida.csv"

    # Se o arquivo não existir ou estiver vazio, escreve o cabeçalho
    if not os.path.exists(arquivo) or os.path.getsize(arquivo) == 0:
        with open(arquivo, "a") as f:
            f.write("TrueSys,PredSys,TrueDia,PredDia,ErroSys,ErroDia\n")

    # Escrita dos valores
    with open(arquivo, "a") as f:
        f.write(f"{avg_true_systolic:.4f},"
                f"{avg_predicted_systolic:.4f},"
                f"{avg_true_diastolic:.4f},"
                f"{avg_predicted_diastolic:.4f},"
                f"{erro_systolic:.4f},"
                f"{erro_diastolic:.4f}\n")

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

for train_idx, test_idx in logo.split(X, y, groups=groups):
    X_train, X_val = X[train_idx], X[test_idx]
    y_train, y_val = y[train_idx], y[test_idx]
    print(f'Train shape: {X_train.shape}, Test shape: {X_val.shape}')

    # define reluthe model
    model = Sequential([
        Input(shape=(300,)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(2)
    ])
    
    optimizer = Adam(learning_rate=0.01)

    model.compile(optimizer=optimizer, loss='mse', metrics=['mae', tf.keras.metrics.MeanAbsolutePercentageError()])
    print(model.summary())
    
    # early stopping callback
    early_stop = EarlyStopping(
        monitor = 'val_loss',
        patience = 10,
        restore_best_weights = True
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=64,
        callbacks=[early_stop]
    )
    
    # Rescale predictions back to original scale
    y_pred = model.predict(X_val)
    y_pred_rescaled = scaler_y.inverse_transform(y_pred)
    y_val_rescaled = scaler_y.inverse_transform(y_val)

    # Evaluate on the original scale
    mae = mean_absolute_error(y_val_rescaled, y_pred_rescaled)
    mape = mean_absolute_percentage_error(y_val_rescaled, y_pred_rescaled)
    loss = mean_squared_error(y_val_rescaled, y_pred_rescaled)
    
    print(f'Test Loss: {loss:.4f} - Test MAE: {mae:.4f} - Test MAPE: {mape:.4f}')

    # plot predictions
    plot_predictions(y_pred_rescaled, y_val_rescaled)

    calc_error_avg_bp(y_pred_rescaled, y_val_rescaled)

    # clear memory
    del model
    tf.keras.backend.clear_session()
# Out:
# Train shape: (14243, 300), Test shape: (1804, 300)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.5800 - mae: 0.5850 - mean_absolute_percentage_error: 424.2826 - val_loss: 4.8184 - val_mae: 1.8783 - val_mean_absolute_percentage_error: 785.7033
# Epoch 2/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3894 - mae: 0.4887 - mean_absolute_percentage_error: 401.0681 - val_loss: 2.9155 - val_mae: 1.4414 - val_mean_absolute_percentage_error: 452.5023
# Epoch 3/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3486 - mae: 0.4620 - mean_absolute_percentage_error: 357.8910 - val_loss: 1.8852 - val_mae: 1.1336 - val_mean_absolute_percentage_error: 282.2574
# Epoch 4/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3331 - mae: 0.4510 - mean_absolute_percentage_error: 363.6348 - val_loss: 2.2578 - val_mae: 1.2501 - val_mean_absolute_percentage_error: 387.1324
# Epoch 5/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3236 - mae: 0.4437 - mean_absolute_percentage_error: 350.5660 - val_loss: 2.5892 - val_mae: 1.3709 - val_mean_absolute_percentage_error: 479.9469
# Epoch 6/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3125 - mae: 0.4363 - mean_absolute_percentage_error: 359.0629 - val_loss: 1.4580 - val_mae: 0.9246 - val_mean_absolute_percentage_error: 161.8691
# Epoch 7/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3206 - mae: 0.4390 - mean_absolute_percentage_error: 343.8407 - val_loss: 1.3964 - val_mae: 0.9145 - val_mean_absolute_percentage_error: 170.6372
# Epoch 8/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3064 - mae: 0.4304 - mean_absolute_percentage_error: 341.3637 - val_loss: 1.3593 - val_mae: 0.9027 - val_mean_absolute_percentage_error: 169.1926
# Epoch 9/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3057 - mae: 0.4297 - mean_absolute_percentage_error: 329.9318 - val_loss: 1.3817 - val_mae: 0.9109 - val_mean_absolute_percentage_error: 177.6741
# Epoch 10/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3015 - mae: 0.4256 - mean_absolute_percentage_error: 314.2254 - val_loss: 1.3546 - val_mae: 0.9061 - val_mean_absolute_percentage_error: 183.7843
# Epoch 11/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2987 - mae: 0.4237 - mean_absolute_percentage_error: 334.1001 - val_loss: 1.4082 - val_mae: 0.9045 - val_mean_absolute_percentage_error: 176.9202
# Epoch 12/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2955 - mae: 0.4223 - mean_absolute_percentage_error: 344.0192 - val_loss: 1.3876 - val_mae: 0.8954 - val_mean_absolute_percentage_error: 169.9766
# Epoch 13/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2956 - mae: 0.4222 - mean_absolute_percentage_error: 326.1906 - val_loss: 1.3924 - val_mae: 0.9129 - val_mean_absolute_percentage_error: 172.7781
# Epoch 14/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2897 - mae: 0.4172 - mean_absolute_percentage_error: 327.2222 - val_loss: 1.4296 - val_mae: 0.9193 - val_mean_absolute_percentage_error: 181.0716
# Epoch 15/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2837 - mae: 0.4134 - mean_absolute_percentage_error: 327.7779 - val_loss: 1.4601 - val_mae: 0.9326 - val_mean_absolute_percentage_error: 181.7571
# Epoch 16/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.2918 - mae: 0.4182 - mean_absolute_percentage_error: 312.5075 - val_loss: 1.5517 - val_mae: 0.9577 - val_mean_absolute_percentage_error: 191.8468
# Epoch 17/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2825 - mae: 0.4120 - mean_absolute_percentage_error: 313.7155 - val_loss: 1.5633 - val_mae: 0.9590 - val_mean_absolute_percentage_error: 193.7975
# Epoch 18/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2868 - mae: 0.4139 - mean_absolute_percentage_error: 336.6691 - val_loss: 1.5392 - val_mae: 0.9477 - val_mean_absolute_percentage_error: 182.4981
# Epoch 19/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2843 - mae: 0.4123 - mean_absolute_percentage_error: 323.7803 - val_loss: 1.4720 - val_mae: 0.9355 - val_mean_absolute_percentage_error: 183.9698
# Epoch 20/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2796 - mae: 0.4090 - mean_absolute_percentage_error: 342.5105 - val_loss: 1.5687 - val_mae: 0.9621 - val_mean_absolute_percentage_error: 199.3401
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test Loss: 319.9441 - Test MAE: 13.8596 - Test MAPE: 0.1294
# Train shape: (13847, 300), Test shape: (2200, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.5133 - mae: 0.5411 - mean_absolute_percentage_error: 342.4217 - val_loss: 5.1554 - val_mae: 1.9969 - val_mean_absolute_percentage_error: 1366.1169
# Epoch 2/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3571 - mae: 0.4705 - mean_absolute_percentage_error: 335.2373 - val_loss: 5.4848 - val_mae: 2.1605 - val_mean_absolute_percentage_error: 1761.3380
# Epoch 3/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3385 - mae: 0.4580 - mean_absolute_percentage_error: 337.8288 - val_loss: 5.6311 - val_mae: 2.2079 - val_mean_absolute_percentage_error: 1860.6154
# Epoch 4/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3221 - mae: 0.4456 - mean_absolute_percentage_error: 326.0672 - val_loss: 6.9031 - val_mae: 2.4981 - val_mean_absolute_percentage_error: 2193.1436
# Epoch 5/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3146 - mae: 0.4407 - mean_absolute_percentage_error: 324.0394 - val_loss: 5.1143 - val_mae: 2.0927 - val_mean_absolute_percentage_error: 1699.0865
# Epoch 6/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3124 - mae: 0.4387 - mean_absolute_percentage_error: 325.1482 - val_loss: 6.2332 - val_mae: 2.3649 - val_mean_absolute_percentage_error: 1998.1191
# Epoch 7/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3200 - mae: 0.4429 - mean_absolute_percentage_error: 322.0680 - val_loss: 4.1017 - val_mae: 1.7945 - val_mean_absolute_percentage_error: 1260.9795
# Epoch 8/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3075 - mae: 0.4339 - mean_absolute_percentage_error: 318.8904 - val_loss: 6.7520 - val_mae: 2.3855 - val_mean_absolute_percentage_error: 1860.9666
# Epoch 9/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2949 - mae: 0.4253 - mean_absolute_percentage_error: 317.2223 - val_loss: 4.5663 - val_mae: 1.9351 - val_mean_absolute_percentage_error: 1496.8063
# Epoch 10/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2921 - mae: 0.4230 - mean_absolute_percentage_error: 312.5801 - val_loss: 4.4927 - val_mae: 1.8866 - val_mean_absolute_percentage_error: 1344.6321
# Epoch 11/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2887 - mae: 0.4199 - mean_absolute_percentage_error: 312.3637 - val_loss: 4.2807 - val_mae: 1.8591 - val_mean_absolute_percentage_error: 1418.4125
# Epoch 12/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2888 - mae: 0.4210 - mean_absolute_percentage_error: 317.7285 - val_loss: 2.4830 - val_mae: 1.3714 - val_mean_absolute_percentage_error: 1027.3271
# Epoch 13/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3042 - mae: 0.4293 - mean_absolute_percentage_error: 310.5629 - val_loss: 5.2652 - val_mae: 2.1509 - val_mean_absolute_percentage_error: 1806.5127
# Epoch 14/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2897 - mae: 0.4212 - mean_absolute_percentage_error: 315.3686 - val_loss: 3.8813 - val_mae: 1.7743 - val_mean_absolute_percentage_error: 1367.4362
# Epoch 15/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2869 - mae: 0.4185 - mean_absolute_percentage_error: 307.4395 - val_loss: 5.3687 - val_mae: 2.1201 - val_mean_absolute_percentage_error: 1667.8613
# Epoch 16/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2834 - mae: 0.4147 - mean_absolute_percentage_error: 316.4334 - val_loss: 5.4035 - val_mae: 2.1303 - val_mean_absolute_percentage_error: 1682.5634
# Epoch 17/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2815 - mae: 0.4146 - mean_absolute_percentage_error: 310.3319 - val_loss: 6.1158 - val_mae: 2.2797 - val_mean_absolute_percentage_error: 1786.3335
# Epoch 18/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2724 - mae: 0.4076 - mean_absolute_percentage_error: 309.3811 - val_loss: 5.7595 - val_mae: 2.2258 - val_mean_absolute_percentage_error: 1796.1198
# Epoch 19/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2673 - mae: 0.4041 - mean_absolute_percentage_error: 298.0533 - val_loss: 4.8898 - val_mae: 2.0311 - val_mean_absolute_percentage_error: 1619.6658
# Epoch 20/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2685 - mae: 0.4048 - mean_absolute_percentage_error: 314.8706 - val_loss: 4.8398 - val_mae: 2.0039 - val_mean_absolute_percentage_error: 1536.7037
# Epoch 21/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2698 - mae: 0.4050 - mean_absolute_percentage_error: 300.6696 - val_loss: 3.2293 - val_mae: 1.6068 - val_mean_absolute_percentage_error: 1244.6650
# Epoch 22/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2711 - mae: 0.4064 - mean_absolute_percentage_error: 302.1470 - val_loss: 3.0228 - val_mae: 1.5471 - val_mean_absolute_percentage_error: 1159.3468
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test Loss: 619.1430 - Test MAE: 21.2193 - Test MAPE: 0.2663
# Train shape: (14100, 300), Test shape: (1947, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.5706 - mae: 0.5824 - mean_absolute_percentage_error: 405.6681 - val_loss: 1.3887 - val_mae: 0.9977 - val_mean_absolute_percentage_error: 1081.5710
# Epoch 2/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3998 - mae: 0.4939 - mean_absolute_percentage_error: 329.5743 - val_loss: 1.0438 - val_mae: 0.8294 - val_mean_absolute_percentage_error: 750.5621
# Epoch 3/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3752 - mae: 0.4774 - mean_absolute_percentage_error: 313.2431 - val_loss: 0.8152 - val_mae: 0.6729 - val_mean_absolute_percentage_error: 556.2643
# Epoch 4/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3528 - mae: 0.4618 - mean_absolute_percentage_error: 325.2693 - val_loss: 0.9907 - val_mae: 0.8051 - val_mean_absolute_percentage_error: 645.6948
# Epoch 5/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3400 - mae: 0.4538 - mean_absolute_percentage_error: 308.0300 - val_loss: 0.8368 - val_mae: 0.6994 - val_mean_absolute_percentage_error: 505.2686
# Epoch 6/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3316 - mae: 0.4469 - mean_absolute_percentage_error: 313.8247 - val_loss: 0.9332 - val_mae: 0.7868 - val_mean_absolute_percentage_error: 659.8035
# Epoch 7/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3242 - mae: 0.4422 - mean_absolute_percentage_error: 314.1039 - val_loss: 0.9388 - val_mae: 0.8027 - val_mean_absolute_percentage_error: 743.6641
# Epoch 8/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3225 - mae: 0.4411 - mean_absolute_percentage_error: 315.3058 - val_loss: 1.0815 - val_mae: 0.8631 - val_mean_absolute_percentage_error: 745.0311
# Epoch 9/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3302 - mae: 0.4459 - mean_absolute_percentage_error: 318.5467 - val_loss: 0.9707 - val_mae: 0.7818 - val_mean_absolute_percentage_error: 633.4962
# Epoch 10/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3158 - mae: 0.4371 - mean_absolute_percentage_error: 328.7987 - val_loss: 1.0249 - val_mae: 0.8134 - val_mean_absolute_percentage_error: 687.7353
# Epoch 11/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3156 - mae: 0.4370 - mean_absolute_percentage_error: 315.5114 - val_loss: 0.8713 - val_mae: 0.7499 - val_mean_absolute_percentage_error: 732.8798
# Epoch 12/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3143 - mae: 0.4362 - mean_absolute_percentage_error: 324.0810 - val_loss: 0.9201 - val_mae: 0.7656 - val_mean_absolute_percentage_error: 660.2112
# Epoch 13/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3094 - mae: 0.4326 - mean_absolute_percentage_error: 325.9121 - val_loss: 1.0866 - val_mae: 0.8478 - val_mean_absolute_percentage_error: 743.2123
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Test Loss: 166.9297 - Test MAE: 9.8796 - Test MAPE: 0.1083
# Train shape: (13681, 300), Test shape: (2366, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 0.5605 - mae: 0.5764 - mean_absolute_percentage_error: 344.2013 - val_loss: 1.0735 - val_mae: 0.7085 - val_mean_absolute_percentage_error: 735.7953
# Epoch 2/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4066 - mae: 0.4993 - mean_absolute_percentage_error: 310.6878 - val_loss: 2.6671 - val_mae: 1.4194 - val_mean_absolute_percentage_error: 2058.9861
# Epoch 3/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3882 - mae: 0.4863 - mean_absolute_percentage_error: 323.7047 - val_loss: 1.1360 - val_mae: 0.8121 - val_mean_absolute_percentage_error: 986.4559
# Epoch 4/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3550 - mae: 0.4637 - mean_absolute_percentage_error: 325.9034 - val_loss: 1.4979 - val_mae: 0.9767 - val_mean_absolute_percentage_error: 1194.9905
# Epoch 5/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3331 - mae: 0.4490 - mean_absolute_percentage_error: 303.3617 - val_loss: 1.4227 - val_mae: 0.9677 - val_mean_absolute_percentage_error: 1349.1566
# Epoch 6/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3239 - mae: 0.4420 - mean_absolute_percentage_error: 297.2487 - val_loss: 1.2799 - val_mae: 0.8734 - val_mean_absolute_percentage_error: 1028.2476
# Epoch 7/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3175 - mae: 0.4372 - mean_absolute_percentage_error: 299.7897 - val_loss: 1.0477 - val_mae: 0.7748 - val_mean_absolute_percentage_error: 775.1167
# Epoch 8/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3129 - mae: 0.4323 - mean_absolute_percentage_error: 289.4410 - val_loss: 1.4517 - val_mae: 0.9542 - val_mean_absolute_percentage_error: 1183.5826
# Epoch 9/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3120 - mae: 0.4319 - mean_absolute_percentage_error: 293.5357 - val_loss: 1.3410 - val_mae: 0.9202 - val_mean_absolute_percentage_error: 1134.6469
# Epoch 10/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3051 - mae: 0.4268 - mean_absolute_percentage_error: 286.0139 - val_loss: 1.9025 - val_mae: 1.1132 - val_mean_absolute_percentage_error: 1491.7872
# Epoch 11/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3012 - mae: 0.4248 - mean_absolute_percentage_error: 298.9069 - val_loss: 1.7500 - val_mae: 1.0386 - val_mean_absolute_percentage_error: 1407.8994
# Epoch 12/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2935 - mae: 0.4183 - mean_absolute_percentage_error: 293.3510 - val_loss: 1.1495 - val_mae: 0.7926 - val_mean_absolute_percentage_error: 922.5837
# Epoch 13/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2939 - mae: 0.4185 - mean_absolute_percentage_error: 293.5778 - val_loss: 1.7223 - val_mae: 0.9690 - val_mean_absolute_percentage_error: 1252.2385
# Epoch 14/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2864 - mae: 0.4128 - mean_absolute_percentage_error: 285.9747 - val_loss: 1.4999 - val_mae: 0.8957 - val_mean_absolute_percentage_error: 1203.5631
# Epoch 15/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2905 - mae: 0.4169 - mean_absolute_percentage_error: 286.9476 - val_loss: 1.4725 - val_mae: 0.8815 - val_mean_absolute_percentage_error: 1174.2797
# Epoch 16/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2880 - mae: 0.4138 - mean_absolute_percentage_error: 292.2220 - val_loss: 1.1508 - val_mae: 0.7685 - val_mean_absolute_percentage_error: 875.2255
# Epoch 17/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2806 - mae: 0.4079 - mean_absolute_percentage_error: 281.5892 - val_loss: 1.0240 - val_mae: 0.7028 - val_mean_absolute_percentage_error: 577.0560
# Epoch 18/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2803 - mae: 0.4080 - mean_absolute_percentage_error: 284.2087 - val_loss: 1.1263 - val_mae: 0.7357 - val_mean_absolute_percentage_error: 803.7548
# Epoch 19/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2813 - mae: 0.4090 - mean_absolute_percentage_error: 297.1654 - val_loss: 1.0134 - val_mae: 0.7278 - val_mean_absolute_percentage_error: 317.0444
# Epoch 20/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2847 - mae: 0.4125 - mean_absolute_percentage_error: 300.8240 - val_loss: 0.9979 - val_mae: 0.7314 - val_mean_absolute_percentage_error: 381.7534
# Epoch 21/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2791 - mae: 0.4074 - mean_absolute_percentage_error: 286.0531 - val_loss: 1.0382 - val_mae: 0.7481 - val_mean_absolute_percentage_error: 268.7713
# Epoch 22/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2781 - mae: 0.4077 - mean_absolute_percentage_error: 284.7588 - val_loss: 1.0294 - val_mae: 0.7328 - val_mean_absolute_percentage_error: 303.2725
# Epoch 23/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2742 - mae: 0.4050 - mean_absolute_percentage_error: 283.2677 - val_loss: 1.0192 - val_mae: 0.7376 - val_mean_absolute_percentage_error: 414.0590
# Epoch 24/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2831 - mae: 0.4106 - mean_absolute_percentage_error: 266.7444 - val_loss: 1.2754 - val_mae: 0.8337 - val_mean_absolute_percentage_error: 528.0406
# Epoch 25/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2897 - mae: 0.4146 - mean_absolute_percentage_error: 280.0454 - val_loss: 1.3078 - val_mae: 0.8839 - val_mean_absolute_percentage_error: 582.5665
# Epoch 26/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2850 - mae: 0.4107 - mean_absolute_percentage_error: 287.0656 - val_loss: 1.2171 - val_mae: 0.7840 - val_mean_absolute_percentage_error: 354.3320
# Epoch 27/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2795 - mae: 0.4080 - mean_absolute_percentage_error: 285.2686 - val_loss: 1.1248 - val_mae: 0.7736 - val_mean_absolute_percentage_error: 341.1974
# Epoch 28/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2724 - mae: 0.4022 - mean_absolute_percentage_error: 284.2654 - val_loss: 1.1294 - val_mae: 0.7731 - val_mean_absolute_percentage_error: 397.8519
# Epoch 29/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2687 - mae: 0.4003 - mean_absolute_percentage_error: 285.4353 - val_loss: 1.2333 - val_mae: 0.8353 - val_mean_absolute_percentage_error: 426.9533
# Epoch 30/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2650 - mae: 0.3968 - mean_absolute_percentage_error: 280.0624 - val_loss: 1.5549 - val_mae: 0.9397 - val_mean_absolute_percentage_error: 477.2428
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Test Loss: 249.1340 - Test MAE: 11.1718 - Test MAPE: 0.1173
# Train shape: (13894, 300), Test shape: (2153, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.5799 - mae: 0.5805 - mean_absolute_percentage_error: 411.1245 - val_loss: 1.0188 - val_mae: 0.8444 - val_mean_absolute_percentage_error: 491.5216
# Epoch 2/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3924 - mae: 0.4897 - mean_absolute_percentage_error: 372.4802 - val_loss: 0.8305 - val_mae: 0.7439 - val_mean_absolute_percentage_error: 355.1809
# Epoch 3/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3636 - mae: 0.4694 - mean_absolute_percentage_error: 355.6784 - val_loss: 0.7199 - val_mae: 0.6864 - val_mean_absolute_percentage_error: 281.0412
# Epoch 4/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3392 - mae: 0.4527 - mean_absolute_percentage_error: 354.2934 - val_loss: 0.8942 - val_mae: 0.7771 - val_mean_absolute_percentage_error: 429.0809
# Epoch 5/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3308 - mae: 0.4451 - mean_absolute_percentage_error: 350.5565 - val_loss: 0.7294 - val_mae: 0.6960 - val_mean_absolute_percentage_error: 301.9632
# Epoch 6/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3222 - mae: 0.4393 - mean_absolute_percentage_error: 352.4560 - val_loss: 0.7985 - val_mae: 0.7161 - val_mean_absolute_percentage_error: 319.8202
# Epoch 7/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3131 - mae: 0.4321 - mean_absolute_percentage_error: 341.0400 - val_loss: 0.8818 - val_mae: 0.7606 - val_mean_absolute_percentage_error: 357.2510
# Epoch 8/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3019 - mae: 0.4226 - mean_absolute_percentage_error: 339.3365 - val_loss: 0.6378 - val_mae: 0.6466 - val_mean_absolute_percentage_error: 233.0092
# Epoch 9/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3079 - mae: 0.4271 - mean_absolute_percentage_error: 339.2101 - val_loss: 0.6082 - val_mae: 0.6252 - val_mean_absolute_percentage_error: 198.0411
# Epoch 10/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3003 - mae: 0.4229 - mean_absolute_percentage_error: 337.6198 - val_loss: 0.5599 - val_mae: 0.6032 - val_mean_absolute_percentage_error: 223.1171
# Epoch 11/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2996 - mae: 0.4214 - mean_absolute_percentage_error: 344.2113 - val_loss: 0.5760 - val_mae: 0.6083 - val_mean_absolute_percentage_error: 219.7474
# Epoch 12/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3004 - mae: 0.4218 - mean_absolute_percentage_error: 338.2964 - val_loss: 0.5131 - val_mae: 0.5738 - val_mean_absolute_percentage_error: 275.3286
# Epoch 13/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2946 - mae: 0.4182 - mean_absolute_percentage_error: 334.7375 - val_loss: 0.5748 - val_mae: 0.6002 - val_mean_absolute_percentage_error: 297.9447
# Epoch 14/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3059 - mae: 0.4234 - mean_absolute_percentage_error: 333.0869 - val_loss: 0.5584 - val_mae: 0.6033 - val_mean_absolute_percentage_error: 241.8982
# Epoch 15/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3004 - mae: 0.4228 - mean_absolute_percentage_error: 332.9697 - val_loss: 0.5624 - val_mae: 0.6098 - val_mean_absolute_percentage_error: 296.4198
# Epoch 16/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2909 - mae: 0.4158 - mean_absolute_percentage_error: 326.6761 - val_loss: 0.5008 - val_mae: 0.5684 - val_mean_absolute_percentage_error: 250.8391
# Epoch 17/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2912 - mae: 0.4154 - mean_absolute_percentage_error: 336.1492 - val_loss: 0.6680 - val_mae: 0.6679 - val_mean_absolute_percentage_error: 354.7415
# Epoch 18/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2915 - mae: 0.4163 - mean_absolute_percentage_error: 329.3804 - val_loss: 0.5809 - val_mae: 0.6232 - val_mean_absolute_percentage_error: 294.0727
# Epoch 19/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2926 - mae: 0.4168 - mean_absolute_percentage_error: 327.3765 - val_loss: 0.6648 - val_mae: 0.6662 - val_mean_absolute_percentage_error: 326.9560
# Epoch 20/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2846 - mae: 0.4111 - mean_absolute_percentage_error: 333.6831 - val_loss: 0.6034 - val_mae: 0.6284 - val_mean_absolute_percentage_error: 285.2463
# Epoch 21/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2808 - mae: 0.4090 - mean_absolute_percentage_error: 329.9291 - val_loss: 0.7132 - val_mae: 0.6938 - val_mean_absolute_percentage_error: 312.7806
# Epoch 22/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2838 - mae: 0.4108 - mean_absolute_percentage_error: 318.1647 - val_loss: 0.5534 - val_mae: 0.5917 - val_mean_absolute_percentage_error: 452.7283
# Epoch 23/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2824 - mae: 0.4092 - mean_absolute_percentage_error: 325.2074 - val_loss: 0.5465 - val_mae: 0.5977 - val_mean_absolute_percentage_error: 349.3360
# Epoch 24/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2840 - mae: 0.4114 - mean_absolute_percentage_error: 320.5946 - val_loss: 0.6213 - val_mae: 0.6364 - val_mean_absolute_percentage_error: 433.4264
# Epoch 25/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2809 - mae: 0.4093 - mean_absolute_percentage_error: 324.6662 - val_loss: 0.5943 - val_mae: 0.6134 - val_mean_absolute_percentage_error: 398.7545
# Epoch 26/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2793 - mae: 0.4062 - mean_absolute_percentage_error: 313.1363 - val_loss: 0.6391 - val_mae: 0.6493 - val_mean_absolute_percentage_error: 328.0565
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test Loss: 125.8390 - Test MAE: 8.8669 - Test MAPE: 0.0883
# Train shape: (13986, 300), Test shape: (2061, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.5778 - mae: 0.5886 - mean_absolute_percentage_error: 367.1193 - val_loss: 0.7653 - val_mae: 0.7348 - val_mean_absolute_percentage_error: 170.4149
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4059 - mae: 0.5008 - mean_absolute_percentage_error: 349.4783 - val_loss: 0.7978 - val_mae: 0.7106 - val_mean_absolute_percentage_error: 266.3437
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3776 - mae: 0.4833 - mean_absolute_percentage_error: 349.9500 - val_loss: 2.2683 - val_mae: 1.1661 - val_mean_absolute_percentage_error: 329.4268
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3659 - mae: 0.4766 - mean_absolute_percentage_error: 359.7016 - val_loss: 1.0229 - val_mae: 0.8087 - val_mean_absolute_percentage_error: 393.8384
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.3558 - mae: 0.4692 - mean_absolute_percentage_error: 347.6993 - val_loss: 1.2616 - val_mae: 0.9257 - val_mean_absolute_percentage_error: 471.5717
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3489 - mae: 0.4643 - mean_absolute_percentage_error: 345.0753 - val_loss: 1.7707 - val_mae: 1.0536 - val_mean_absolute_percentage_error: 450.7860
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3423 - mae: 0.4590 - mean_absolute_percentage_error: 346.8210 - val_loss: 0.7861 - val_mae: 0.7592 - val_mean_absolute_percentage_error: 356.3640
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3435 - mae: 0.4598 - mean_absolute_percentage_error: 353.7213 - val_loss: 1.2206 - val_mae: 0.9021 - val_mean_absolute_percentage_error: 208.0253
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3364 - mae: 0.4543 - mean_absolute_percentage_error: 343.6088 - val_loss: 0.9123 - val_mae: 0.7849 - val_mean_absolute_percentage_error: 261.6636
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3305 - mae: 0.4507 - mean_absolute_percentage_error: 348.2350 - val_loss: 1.0419 - val_mae: 0.8377 - val_mean_absolute_percentage_error: 247.8076
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3230 - mae: 0.4449 - mean_absolute_percentage_error: 337.7357 - val_loss: 0.9979 - val_mae: 0.8208 - val_mean_absolute_percentage_error: 251.3901
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test Loss: 213.4887 - Test MAE: 11.7445 - Test MAPE: 0.1449
# Train shape: (14467, 300), Test shape: (1580, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.5661 - mae: 0.5778 - mean_absolute_percentage_error: 403.2945 - val_loss: 0.7857 - val_mae: 0.7396 - val_mean_absolute_percentage_error: 448.4278
# Epoch 2/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3888 - mae: 0.4877 - mean_absolute_percentage_error: 363.5249 - val_loss: 0.9201 - val_mae: 0.8066 - val_mean_absolute_percentage_error: 475.1535
# Epoch 3/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3593 - mae: 0.4687 - mean_absolute_percentage_error: 344.0576 - val_loss: 0.9902 - val_mae: 0.8370 - val_mean_absolute_percentage_error: 462.5734
# Epoch 4/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3560 - mae: 0.4662 - mean_absolute_percentage_error: 346.7596 - val_loss: 0.7422 - val_mae: 0.7024 - val_mean_absolute_percentage_error: 376.8912
# Epoch 5/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3453 - mae: 0.4589 - mean_absolute_percentage_error: 347.1935 - val_loss: 0.6545 - val_mae: 0.6393 - val_mean_absolute_percentage_error: 326.2402
# Epoch 6/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3383 - mae: 0.4538 - mean_absolute_percentage_error: 329.4531 - val_loss: 0.6714 - val_mae: 0.6384 - val_mean_absolute_percentage_error: 235.5421
# Epoch 7/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3278 - mae: 0.4457 - mean_absolute_percentage_error: 340.1136 - val_loss: 0.7479 - val_mae: 0.6927 - val_mean_absolute_percentage_error: 343.3830
# Epoch 8/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3198 - mae: 0.4404 - mean_absolute_percentage_error: 337.1355 - val_loss: 0.7682 - val_mae: 0.6886 - val_mean_absolute_percentage_error: 189.5933
# Epoch 9/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3110 - mae: 0.4344 - mean_absolute_percentage_error: 330.7647 - val_loss: 0.7506 - val_mae: 0.6805 - val_mean_absolute_percentage_error: 177.3198
# Epoch 10/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3102 - mae: 0.4332 - mean_absolute_percentage_error: 325.0042 - val_loss: 0.8792 - val_mae: 0.7463 - val_mean_absolute_percentage_error: 247.3368
# Epoch 11/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3030 - mae: 0.4277 - mean_absolute_percentage_error: 329.3221 - val_loss: 0.7289 - val_mae: 0.6715 - val_mean_absolute_percentage_error: 193.6553
# Epoch 12/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2998 - mae: 0.4262 - mean_absolute_percentage_error: 327.9164 - val_loss: 0.7059 - val_mae: 0.6658 - val_mean_absolute_percentage_error: 168.7629
# Epoch 13/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2983 - mae: 0.4250 - mean_absolute_percentage_error: 321.5626 - val_loss: 0.7252 - val_mae: 0.6748 - val_mean_absolute_percentage_error: 176.0769
# Epoch 14/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2985 - mae: 0.4248 - mean_absolute_percentage_error: 300.1270 - val_loss: 0.7067 - val_mae: 0.6764 - val_mean_absolute_percentage_error: 257.1992
# Epoch 15/50
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3050 - mae: 0.4305 - mean_absolute_percentage_error: 319.1456 - val_loss: 0.8075 - val_mae: 0.7210 - val_mean_absolute_percentage_error: 383.1518
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Loss: 159.1644 - Test MAE: 9.7763 - Test MAPE: 0.1071
# Train shape: (14111, 300), Test shape: (1936, 300)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,410 (83.63 KB)
#  Trainable params: 21,410 (83.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.4834 - mae: 0.5330 - mean_absolute_percentage_error: 392.5653 - val_loss: 0.8398 - val_mae: 0.7537 - val_mean_absolute_percentage_error: 247.2889
# Epoch 2/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3603 - mae: 0.4646 - mean_absolute_percentage_error: 326.5598 - val_loss: 1.4597 - val_mae: 1.0056 - val_mean_absolute_percentage_error: 397.8486
# Epoch 3/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3306 - mae: 0.4460 - mean_absolute_percentage_error: 332.3026 - val_loss: 1.2885 - val_mae: 0.9360 - val_mean_absolute_percentage_error: 349.5753
# Epoch 4/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3133 - mae: 0.4340 - mean_absolute_percentage_error: 339.5022 - val_loss: 1.2131 - val_mae: 0.9069 - val_mean_absolute_percentage_error: 321.8013
# Epoch 5/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3102 - mae: 0.4322 - mean_absolute_percentage_error: 347.0434 - val_loss: 1.0857 - val_mae: 0.8484 - val_mean_absolute_percentage_error: 267.8762
# Epoch 6/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2999 - mae: 0.4254 - mean_absolute_percentage_error: 354.4313 - val_loss: 1.0395 - val_mae: 0.8301 - val_mean_absolute_percentage_error: 253.5245
# Epoch 7/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3029 - mae: 0.4270 - mean_absolute_percentage_error: 346.9989 - val_loss: 1.0912 - val_mae: 0.8421 - val_mean_absolute_percentage_error: 230.3846
# Epoch 8/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2943 - mae: 0.4214 - mean_absolute_percentage_error: 365.2405 - val_loss: 1.0578 - val_mae: 0.8294 - val_mean_absolute_percentage_error: 215.4956
# Epoch 9/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2910 - mae: 0.4200 - mean_absolute_percentage_error: 346.2387 - val_loss: 0.8671 - val_mae: 0.7441 - val_mean_absolute_percentage_error: 203.8385
# Epoch 10/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2924 - mae: 0.4220 - mean_absolute_percentage_error: 344.8483 - val_loss: 0.8483 - val_mae: 0.7402 - val_mean_absolute_percentage_error: 241.6639
# Epoch 11/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2926 - mae: 0.4213 - mean_absolute_percentage_error: 347.4066 - val_loss: 1.0142 - val_mae: 0.8077 - val_mean_absolute_percentage_error: 219.7237
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test Loss: 204.1364 - Test MAE: 11.5471 - Test MAPE: 0.1512

# %%
# reshape to (samples, timesteps, features)
X = X.reshape((-1, 3, 100))
X = np.transpose(X, (0, 2, 1))
X.shape, y.shape

# %%
param_grid = {
        'CLASSIFICADOR': 'LSTM',
        'RECURRENT_LAYERS': (64, 32),
        'DENSE_LAYERS': (64, 32),
        'BATCH_SIZE': 32,
        'LEARNING_RATE': 0.01,
        'EPOCHS': 100,
        'ACTIVATION': 'relu',
        'OPTIMIZER': 'adam'
    }

# %%
logo = LeaveOneGroupOut()

# %%
for train_idx, test_idx in logo.split(X, y, groups=groups):
    X_train, X_val = X[train_idx], X[test_idx]
    y_train, y_val = y[train_idx], y[test_idx]
    print(f'Train shape: {X_train.shape}, Test shape: {X_val.shape}')

    # define the model
    model = Sequential([
        Input(shape=(300,)),
        Dense(param_grid['DENSE_LAYERS'][0], activation='relu'),
        Dense(2, activation='linear')
    ])
    
    # Choose optimizer with learning rate
    if param_grid['OPTIMIZER'] == 'adam':
        optimizer = Adam(learning_rate=param_grid['LEARNING_RATE'])
    elif param_grid['OPTIMIZER'] == 'sgd':
        optimizer = SGD(learning_rate=param_grid['LEARNING_RATE'])

    model.compile(optimizer=optimizer, loss='mse', metrics=['mae', tf.keras.metrics.MeanAbsolutePercentageError()])
    print(model.summary())
    
    # early stopping callback
    early_stop = EarlyStopping(
        monitor = 'val_loss',
        patience = 5,
        restore_best_weights = True
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=param_grid['EPOCHS'],
        batch_size=param_grid['BATCH_SIZE'],
        callbacks=[early_stop]
    )
    
    # Rescale predictions back to original scale
    y_pred = model.predict(X_val)
    y_pred_rescaled = scaler_y.inverse_transform(y_pred)
    y_val_rescaled = scaler_y.inverse_transform(y_val)

    # Evaluate on the original scale
    mae = mean_absolute_error(y_val_rescaled, y_pred_rescaled)
    mape = mean_absolute_percentage_error(y_val_rescaled, y_pred_rescaled)
    loss = mean_squared_error(y_val_rescaled, y_pred_rescaled)
    
    print(f'Test Loss: {loss:.4f} - Test MAE: {mae:.4f} - Test MAPE: {mape:.4f}')

    # plot predictions
    plot_predictions(y_pred_rescaled, y_val_rescaled)

    # clear memory
    del model
    tf.keras.backend.clear_session()
